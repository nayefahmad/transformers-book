# %%
# !pip install --upgrade google-cloud-vision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.0/444.0 kB 5.9 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: google-cloud-vision
#     Found existing installation: google-cloud-vision 2.8.0
#     Uninstalling google-cloud-vision-2.8.0:
#       Successfully uninstalled google-cloud-vision-2.8.0
# ...

# %%
from google.cloud import vision

# %%
def run_quickstart(img_url: str) -> vision.EntityAnnotation:
    """Provides a quick start example for Cloud Vision."""

    # Instantiates a client
    client = vision.ImageAnnotatorClient()

    # The URI of the image file to annotate
    file_uri = img_url

    image = vision.Image()
    image.source.image_uri = file_uri

    # Performs label detection on the image file
    response = client.label_detection(image=image)
    labels = response.label_annotations

    print("Labels:")
    for label in labels:
        print(label.description)

    return labels

# %%
def detect_properties(img_url: str):
    """Detects image properties in the file."""

    client = vision.ImageAnnotatorClient()

    # The URI of the image file to annotate
    image = vision.Image()
    image.source.image_uri = img_url

    response = client.image_properties(image=image)
    props = response.image_properties_annotation
    print("Properties:")

    for color in props.dominant_colors.colors:
        print(f"fraction: {color.pixel_fraction}")
        print(f"\tr: {color.color.red}")
        print(f"\tg: {color.color.green}")
        print(f"\tb: {color.color.blue}")
        print(f"\ta: {color.color.alpha}")

    if response.error.message:
        raise Exception(
            "{}\nFor more info on error messages, check: "
            "https://cloud.google.com/apis/design/errors".format(response.error.message)
        )

# %%
img_urls = [
    'https://thebooktrail.files.wordpress.com/2014/02/71h2sjik5al-_sl1380_.jpg?w=306&h=488&zoom=2', 
    'https://flxt.tmsimg.com/assets/p18721_p_v8_aj.jpg', 
    'https://www.foodandwine.com/thmb/tM060YA0Fd0UALCmPQ-5gGWyBqA=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Classic-Club-Sandwich-FT-RECIPE0523-99327c9c87214026b9419b949ee13a9c.jpg', 
    'https://upload.wikimedia.org/wikipedia/commons/7/7d/N700a-Mt.Fuji.jpg',
    'https://pbs.twimg.com/profile_images/1575486829356122115/K9zDF6YG_400x400.jpg',
    'https://images.pexels.com/photos/2693212/pexels-photo-2693212.png?cs=srgb&dl=pexels-anni-roenkae-2693212.jpg&fm=jpg', 
]

# %%
for img in img_urls: 
    print(f'url={img}')
    run_quickstart(img)
    print('done ------------------------------------------\n\n')
# Out:
# url=https://thebooktrail.files.wordpress.com/2014/02/71h2sjik5al-_sl1380_.jpg?w=306&h=488&zoom=2
# Labels:
# Book
# Font
# Publication
# Book cover
# Art
# Illustration
# Event
# Signature
# Fiction
# History
# done ------------------------------------------
#
#
# url=https://flxt.tmsimg.com/assets/p18721_p_v8_aj.jpg
# Labels:
# Smile
# Sports uniform
# Vest
# Poster
# Sleeveless shirt
# Font
# Fictional character
# Jersey
# Art
# Logo
# done ------------------------------------------
#
#
# url=https://www.foodandwine.com/thmb/tM060YA0Fd0UALCmPQ-5gGWyBqA=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Classic-Club-Sandwich-FT-RECIPE0523-99327c9c87214026b9419b949ee13a9c.jpg
# Labels:
# Food
# Tableware
# Ingredient
# Sandwich
# Cuisine
# Baked goods
# Red russian
# Fast food
# Punsch
# Drinkware
# done ------------------------------------------
#
#
# url=https://upload.wikimedia.org/wikipedia/commons/7/7d/N700a-Mt.Fuji.jpg
# Labels:
# Sky
# Mountain
# Cloud
# Train
# ...

# %%
for img in img_urls: 
    print(f'url={img}')
    detect_properties(img)
    print('done ------------------------------------------\n\n')
# Out:
# url=https://thebooktrail.files.wordpress.com/2014/02/71h2sjik5al-_sl1380_.jpg?w=306&h=488&zoom=2
# Properties:
# fraction: 0.4532005488872528
# 	r: 228.0
# 	g: 224.0
# 	b: 182.0
# 	a:
# fraction: 0.025113660842180252
# 	r: 66.0
# 	g: 52.0
# 	b: 34.0
# 	a:
# fraction: 0.007577397860586643
# 	r: 77.0
# 	g: 53.0
# 	b: 50.0
# 	a:
# fraction: 0.00772172911092639
# 	r: 68.0
# 	g: 51.0
# 	b: 46.0
# 	a:
# fraction: 0.23013639450073242
# 	r: 213.0
# 	g: 206.0
# 	b: 165.0
# 	a:
# fraction: 0.01955690234899521
# 	r: 92.0
# 	g: 78.0
# 	b: 56.0
# 	a:
# fraction: 0.002525799209252
# 	r: 80.0
# 	g: 53.0
# 	b: 45.0
# 	a:
# fraction: 0.15162011981010437
# 	r: 213.0
# 	g: 205.0
# 	b: 152.0
# 	a:
# fraction: 0.017897091805934906
# 	r: 130.0
# 	g: 119.0
# 	b: 91.0
# 	a:
# fraction: 0.028505448251962662
# 	r: 164.0
# 	g: 155.0
# 	b: 122.0
# 	a:
# done ------------------------------------------
#
#
# url=https://flxt.tmsimg.com/assets/p18721_p_v8_aj.jpg
# Properties:
# fraction: 0.067133329808712
# ...
